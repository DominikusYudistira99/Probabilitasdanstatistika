# %% [markdown]
# # Import Dataset Iris dan Wine Review

# %%
import pandas as pd
iris = pd.read_csv('iris.csv', names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'])
print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
wine_reviews= pd.read_csv('winemag-data-130k-v2.csv',index_col=0)
wine_reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Scatter Plot

# %%
fig,ax = plt.subplots()

ax.scatter(iris['sepal_length'],iris['sepal_width'])
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %%
colors = {'Iris-setosa':'r', 'Iris-versicolor':'g', 'Iris-virginica':'b'}

fig, ax = plt.subplots()

for i in range(len(iris['sepal_length'])):
    ax.scatter(iris['sepal_length'][i], iris['sepal_width'][i],color=colors[iris['class'][i]])
    
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %% [markdown]
# # Line Chart

# %%
columns = iris.columns.drop(['class'])

x_data = range(0, iris.shape[0])

fig, ax = plt.subplots()

for column in columns:
    ax.plot(x_data, iris[column])
    
ax.set_title('Iris Dataset')
ax.legend(columns)

# %%
import matplotlib.pyplot
from numpy import sin

# consistent interval for x-axis
x = [x*0.1 for x in range(100)]

# function of x for y-axis
y = sin(x)

# createline plot
matplotlib.pyplot.plot(x, y)
matplotlib.pyplot.show()

# %% [markdown]
# # Histogram

# %%
fig, ax = plt.subplots()

ax.hist(wine_reviews['points'])

ax.set_title('Wine Review Scores')
ax.set_xlabel('Points')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # Bar Chart

# %%
fig, ax = plt.subplots()

data = wine_reviews['points'].value_counts()

points = data.index
frequency = data.values

ax.bar(points, frequency)

ax.set_title('Wine Review Scores')
ax.set_xlabel('Points')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %% [markdown]
# # Scatter Plot

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', data=iris)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lineplot(data=iris.drop(['class'], axis=1))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Histogram

# %%
sns.distplot(wine_reviews['points'], bins=10, kde=False)
# Out:
# C:\Users\yudis\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='points'>

# %%
sns.distplot(wine_reviews['points'], bins=10, kde=True)
# Out:
# <AxesSubplot:xlabel='points', ylabel='Density'>

# %% [markdown]
# # Bar Chart

# %%
sns.countplot(wine_reviews['points'])
# Out:
# C:\Users\yudis\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='points', ylabel='count'>

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(iris)

# %% [markdown]
# # Pertanyaan

# %%
print("1. Jelaskan kemungkinan hubungan yang terjadi secara pairwaise variabel-variabel yang ada di dataset iris berdasarkan hasil pairplot!");
print("2.Buatlah Histogram di seaborn menggunakan bin=5,bin=10,bin=12 dan bin=15.Jelaskan Mengapa histogram bisa berbeda!");
print("3. Tuliskan beberapa jumlah variabel dan datapoin di dataset Iris");
print("4. Tuliskan beberapa jumlah variabel dan datapoin di dataset Wine Review");
# Out:
# 1. Jelaskan kemungkinan hubungan yang terjadi secara pairwaise variabel-variabel yang ada di dataset iris berdasarkan hasil pairplot!
# 2.Buatlah Histogram di seaborn menggunakan bin=5,bin=10,bin=12 dan bin=15.Jelaskan Mengapa histogram bisa berbeda!
# 3. Tuliskan beberapa jumlah variabel dan datapoin di dataset Iris
# 4. Tuliskan beberapa jumlah variabel dan datapoin di dataset Wine Review

# %% [markdown]
# # Jawaban

# %%
print ( "3. Jumlah Variabel dan data poin Iris : 5" );
print ( "4. Jumlah Variabel dan data poin Wine Review : 13");
# Out:
# 3. Jumlah Variabel dan data poin Iris : 5
# 4. Jumlah Variabel dan data poin Wine Review : 13
